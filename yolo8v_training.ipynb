# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt') 
results = model.train(data="YOLO_person_dataset_v2_4k_NEW\data.yaml", batch=-1, epochs=150)
# Out:
# New https://pypi.org/project/ultralytics/8.0.202 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.201  Python-3.11.6 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# ...
